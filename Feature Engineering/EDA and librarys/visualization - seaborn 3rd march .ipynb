# %%
import seaborn as sns

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# only for practice to load dataset

#iris2 = sns.load_dataset('titanic')

# %%
#iris2

# %%
sns.scatterplot(x=iris.sepal_length , y=iris.sepal_width )
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.barplot(x=iris.sepal_length , y=iris.sepal_width )
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x=iris.sepal_length , y=iris.petal_length )
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.barplot(x=iris.sepal_length , y=iris.petal_length )
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(x=iris.sepal_length , y=iris.petal_width )
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='petal_width'>

# %%
sns.barplot(x=iris.sepal_length , y=iris.petal_width )
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='petal_width'>

# %%
sns.scatterplot(x=iris.sepal_width , y=iris.petal_length )
# Out:
# <AxesSubplot: xlabel='sepal_width', ylabel='petal_length'>

# %%
sns.barplot(x=iris.sepal_width , y=iris.petal_length )
# Out:
# <AxesSubplot: xlabel='sepal_width', ylabel='petal_length'>

# %%
sns.scatterplot(x=iris.sepal_width , y=iris.petal_width)
# Out:
# <AxesSubplot: xlabel='sepal_width', ylabel='petal_width'>

# %%
sns.barplot(x=iris.sepal_width , y=iris.petal_width)
# Out:
# <AxesSubplot: xlabel='sepal_width', ylabel='petal_width'>

# %%
sns.scatterplot(x=iris.petal_length , y=iris.petal_width)
# Out:
# <AxesSubplot: xlabel='petal_length', ylabel='petal_width'>

# %%
sns.barplot(x=iris.petal_length , y=iris.petal_width)
# Out:
# <AxesSubplot: xlabel='petal_length', ylabel='petal_width'>

# %%
sns.displot(iris['sepal_length'])

# %%
titanic = sns.load_dataset("titanic")

# %%
sns.pairplot(iris)

# %%
sns.pairplot(titanic)
# Out:
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
sns.jointplot(iris)

# %%
sns.jointplot(titanic)

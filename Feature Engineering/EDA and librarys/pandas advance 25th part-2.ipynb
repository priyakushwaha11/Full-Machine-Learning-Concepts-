# %%
import pandas as pd

# %%
df = pd.read_csv('data_science_job.csv.zip')

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df.columns
# Out:
# Index(['enrollee_id', 'city', 'city_development_index', 'gender',
#        'relevent_experience', 'enrolled_university', 'education_level',
#        'major_discipline', 'experience', 'company_size', 'company_type',
#        'training_hours', 'target'],
#       dtype='object')

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline  experience company_size    company_type  training_hours  \
# 0             STEM        20.0          NaN             NaN            36.0
# 1             STEM        15.0        50-99         Pvt Ltd            47.0
# ...

# %%
#kisi column ko delete karne ke liye drop function use karte hai lekin ushke liye column ka name nhi likhte axis=index(0,1,3,4,5,) ka use karte hain
df.drop('enrollee_id',axis=1)
# Out:
#            city  city_development_index gender      relevent_experience  \
# 0      city_103                   0.920   Male  Has relevent experience
# 1       city_40                   0.776   Male   No relevent experience
# 2       city_21                   0.624    NaN   No relevent experience
# 3      city_115                   0.789    NaN   No relevent experience
# 4      city_162                   0.767   Male  Has relevent experience
# ...         ...                     ...    ...                      ...
# 19153  city_173                   0.878   Male   No relevent experience
# 19154  city_103                   0.920   Male  Has relevent experience
# 19155  city_103                   0.920   Male  Has relevent experience
# 19156   city_65                   0.802   Male  Has relevent experience
# 19157   city_67                   0.855    NaN   No relevent experience
#
#       enrolled_university education_level major_discipline  experience  \
# ...

# %%
#lekin abhi bhi data se poori tarike se nhi hta hai
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
#data se poori tarike se hatane ke liye inplace = True function use karte hai
df.drop('enrollee_id',axis=1,inplace=True)

# %%
df
# Out:
#            city  city_development_index gender      relevent_experience  \
# 0      city_103                   0.920   Male  Has relevent experience
# 1       city_40                   0.776   Male   No relevent experience
# 2       city_21                   0.624    NaN   No relevent experience
# 3      city_115                   0.789    NaN   No relevent experience
# 4      city_162                   0.767   Male  Has relevent experience
# ...         ...                     ...    ...                      ...
# 19153  city_173                   0.878   Male   No relevent experience
# 19154  city_103                   0.920   Male  Has relevent experience
# 19155  city_103                   0.920   Male  Has relevent experience
# 19156   city_65                   0.802   Male  Has relevent experience
# 19157   city_67                   0.855    NaN   No relevent experience
#
#       enrolled_university education_level major_discipline  experience  \
# ...

# %%
df.set_index("gender")
# Out:
#             city  city_development_index      relevent_experience  \
# gender
# Male    city_103                   0.920  Has relevent experience
# Male     city_40                   0.776   No relevent experience
# NaN      city_21                   0.624   No relevent experience
# NaN     city_115                   0.789   No relevent experience
# Male    city_162                   0.767  Has relevent experience
# ...          ...                     ...                      ...
# Male    city_173                   0.878   No relevent experience
# Male    city_103                   0.920  Has relevent experience
# Male    city_103                   0.920  Has relevent experience
# Male     city_65                   0.802  Has relevent experience
# NaN      city_67                   0.855   No relevent experience
#
#        enrolled_university education_level major_discipline  experience  \
# gender
# Male         no_enrollment        Graduate             STEM        20.0
# ...

# %%
df.reset_index()
# Out:
#        index      city  city_development_index gender  \
# 0          0  city_103                   0.920   Male
# 1          1   city_40                   0.776   Male
# 2          2   city_21                   0.624    NaN
# 3          3  city_115                   0.789    NaN
# 4          4  city_162                   0.767   Male
# ...      ...       ...                     ...    ...
# 19153  19153  city_173                   0.878   Male
# 19154  19154  city_103                   0.920   Male
# 19155  19155  city_103                   0.920   Male
# 19156  19156   city_65                   0.802   Male
# 19157  19157   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# ...

# %%
d = {
    'key1' : [1,2,3,4,5],
    'key2' : [6,7,8,9,7],
    'key3' : [1,2,3,4,56]
}

# %%
d
# Out:
# {'key1': [1, 2, 3, 4, 5], 'key2': [6, 7, 8, 9, 7], 'key3': [1, 2, 3, 4, 56]}

# %%
#dictionary ko dataframe me change karna
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     6     1
# 1     2     7     2
# 2     3     8     3
# 3     4     9     4
# 4     5     7    56

# %%
#dropna lagane par nan value bhi gayab ho jati hai

# %%
# fillna se nan value ki jagah jo input do fill ho jata hai

# %%
df.isnull()
# Out:
#         city  city_development_index  gender  relevent_experience  \
# 0      False                   False   False                False
# 1      False                   False   False                False
# 2      False                   False    True                False
# 3      False                   False    True                False
# 4      False                   False   False                False
# ...      ...                     ...     ...                  ...
# 19153  False                   False   False                False
# 19154  False                   False   False                False
# 19155  False                   False   False                False
# 19156  False                   False   False                False
# 19157  False                   False    True                False
#
#        enrolled_university  education_level  major_discipline  experience  \
# 0                    False            False             False       False
# ...

# %%
df.fillna("priya")
# Out:
#            city city_development_index gender      relevent_experience  \
# 0      city_103                   0.92   Male  Has relevent experience
# 1       city_40                  0.776   Male   No relevent experience
# 2       city_21                  0.624  priya   No relevent experience
# 3      city_115                  0.789  priya   No relevent experience
# 4      city_162                  0.767   Male  Has relevent experience
# ...         ...                    ...    ...                      ...
# 19153  city_173                  0.878   Male   No relevent experience
# 19154  city_103                   0.92   Male  Has relevent experience
# 19155  city_103                   0.92   Male  Has relevent experience
# 19156   city_65                  0.802   Male  Has relevent experience
# 19157   city_67                  0.855  priya   No relevent experience
#
#       enrolled_university education_level major_discipline experience  \
# ...

# %%
df
# Out:
#            city  city_development_index gender      relevent_experience  \
# 0      city_103                   0.920   Male  Has relevent experience
# 1       city_40                   0.776   Male   No relevent experience
# 2       city_21                   0.624    NaN   No relevent experience
# 3      city_115                   0.789    NaN   No relevent experience
# 4      city_162                   0.767   Male  Has relevent experience
# ...         ...                     ...    ...                      ...
# 19153  city_173                   0.878   Male   No relevent experience
# 19154  city_103                   0.920   Male  Has relevent experience
# 19155  city_103                   0.920   Male  Has relevent experience
# 19156   city_65                   0.802   Male  Has relevent experience
# 19157   city_67                   0.855    NaN   No relevent experience
#
#       enrolled_university education_level major_discipline  experience  \
# ...

# %%
g = df.groupby('experience')

# %%
g

# %%
g.sum()
# Out:
# C:\Users\Smart\AppData\Local\Temp\ipykernel_9392\1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#             city_development_index  training_hours  target
# experience
# 0.0                        376.554         30318.0   237.0
# 1.0                        410.999         34869.0   233.0
# 2.0                        861.122         69213.0   374.0
# 3.0                       1027.053         84800.0   478.0
# 4.0                       1085.671         87756.0   457.0
# 5.0                       1119.553         91711.0   412.0
# 6.0                        955.533         77955.0   343.0
# 7.0                        812.521         63276.0   303.0
# 8.0                        638.035         51896.0   195.0
# 9.0                        799.472         58451.0   213.0
# ...

# %%
len(g)
# Out:
# 21

# %%
df.T
# T for transpose mtlb full rotate , row ka column aur column ka row
# Out:
#                                           0                       1      \
# city                                   city_103                 city_40
# city_development_index                     0.92                   0.776
# gender                                     Male                    Male
# relevent_experience     Has relevent experience  No relevent experience
# enrolled_university               no_enrollment           no_enrollment
# education_level                        Graduate                Graduate
# major_discipline                           STEM                    STEM
# experience                                 20.0                    15.0
# company_size                                NaN                   50-99
# company_type                                NaN                 Pvt Ltd
# training_hours                             36.0                    47.0
# target                                      1.0                     0.0
#
# ...

# %%
df
# Out:
#            city  city_development_index gender      relevent_experience  \
# 0      city_103                   0.920   Male  Has relevent experience
# 1       city_40                   0.776   Male   No relevent experience
# 2       city_21                   0.624    NaN   No relevent experience
# 3      city_115                   0.789    NaN   No relevent experience
# 4      city_162                   0.767   Male  Has relevent experience
# ...         ...                     ...    ...                      ...
# 19153  city_173                   0.878   Male   No relevent experience
# 19154  city_103                   0.920   Male  Has relevent experience
# 19155  city_103                   0.920   Male  Has relevent experience
# 19156   city_65                   0.802   Male  Has relevent experience
# 19157   city_67                   0.855    NaN   No relevent experience
#
#       enrolled_university education_level major_discipline  experience  \
# ...

# %%
# subset banane ka tarika
dfs1 = df[['relevent_experience','enrolled_university','education_level']][0:9]

# %%
dfs2 =  df[['relevent_experience','enrolled_university','education_level']][9:21]

# %%
dfs2
# Out:
#         relevent_experience enrolled_university education_level
# 9   Has relevent experience       no_enrollment        Graduate
# 10   No relevent experience    Full time course     High School
# 11  Has relevent experience       no_enrollment        Graduate
# 12  Has relevent experience       no_enrollment        Graduate
# 13   No relevent experience                 NaN             NaN
# 14   No relevent experience    Full time course     High School
# 15  Has relevent experience       no_enrollment        Graduate
# 16  Has relevent experience       no_enrollment        Graduate
# 17  Has relevent experience       no_enrollment        Graduate
# 18  Has relevent experience       no_enrollment        Graduate
# 19  Has relevent experience       no_enrollment        Graduate
# 20  Has relevent experience       no_enrollment         Masters

# %%
# dono subset ko merge karne ka tarika
pd.concat([dfs1,dfs2])
# Out:
#         relevent_experience enrolled_university education_level
# 0   Has relevent experience       no_enrollment        Graduate
# 1    No relevent experience       no_enrollment        Graduate
# 2    No relevent experience    Full time course        Graduate
# 3    No relevent experience                 NaN        Graduate
# 4   Has relevent experience       no_enrollment         Masters
# 5   Has relevent experience    Part time course        Graduate
# 6   Has relevent experience       no_enrollment     High School
# 7   Has relevent experience       no_enrollment        Graduate
# 8   Has relevent experience       no_enrollment        Graduate
# 9   Has relevent experience       no_enrollment        Graduate
# 10   No relevent experience    Full time course     High School
# 11  Has relevent experience       no_enrollment        Graduate
# 12  Has relevent experience       no_enrollment        Graduate
# 13   No relevent experience                 NaN             NaN
# ...

# %%
#horizontal concat karne ke liye
df2 = pd.concat([dfs1,dfs2],axis=1)

# %%
df2
# Out:
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience       no_enrollment        Graduate
# 1    No relevent experience       no_enrollment        Graduate
# 2    No relevent experience    Full time course        Graduate
# 3    No relevent experience                 NaN        Graduate
# 4   Has relevent experience       no_enrollment         Masters
# 5   Has relevent experience    Part time course        Graduate
# 6   Has relevent experience       no_enrollment     High School
# 7   Has relevent experience       no_enrollment        Graduate
# 8   Has relevent experience       no_enrollment        Graduate
# 9                       NaN                 NaN             NaN
# 10                      NaN                 NaN             NaN
# 11                      NaN                 NaN             NaN
# 12                      NaN                 NaN             NaN
# 13                      NaN                 NaN             NaN
# ...

# %%
df2.fillna('priya')
# Out:
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience       no_enrollment        Graduate
# 1    No relevent experience       no_enrollment        Graduate
# 2    No relevent experience    Full time course        Graduate
# 3    No relevent experience               priya        Graduate
# 4   Has relevent experience       no_enrollment         Masters
# 5   Has relevent experience    Part time course        Graduate
# 6   Has relevent experience       no_enrollment     High School
# 7   Has relevent experience       no_enrollment        Graduate
# 8   Has relevent experience       no_enrollment        Graduate
# 9                     priya               priya           priya
# 10                    priya               priya           priya
# 11                    priya               priya           priya
# 12                    priya               priya           priya
# 13                    priya               priya           priya
# ...

# %%
data1 = pd.DataFrame({
    'key1' : [1,2,4,5,6,7],
    'key2': [9,8,7,6,5,4],
    'key3' : [11,43,56,76,87,98]
})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     9    11
# 1     2     8    43
# 2     4     7    56
# 3     5     6    76
# 4     6     5    87
# 5     7     4    98

# %%
data2 =pd.DataFrame ({
    'key9' : [23,45,75,56,78,78],
    'key2' : [32,45,76,78,67,56],
    'key7' : [45,76,86,45,44,57]
})

# %%
data2
# Out:
#    key9  key2  key7
# 0    23    32    45
# 1    45    45    76
# 2    75    76    86
# 3    56    78    45
# 4    78    67    44
# 5    78    56    57

# %%
pd.merge(data1,data2)
# Out:
# Empty DataFrame
# Columns: [key1, key2, key3, key9, key7]
# Index: []

# %%
pd.merge(data1,data2,how = 'left')
# Out:
#    key1  key2  key3  key9  key7
# 0     1     9    11   NaN   NaN
# 1     2     8    43   NaN   NaN
# 2     4     7    56   NaN   NaN
# 3     5     6    76   NaN   NaN
# 4     6     5    87   NaN   NaN
# 5     7     4    98   NaN   NaN

# %%
pd.merge(data1,data2,how = 'right')
# Out:
#    key1  key2  key3  key9  key7
# 0   NaN    32   NaN    23    45
# 1   NaN    45   NaN    45    76
# 2   NaN    76   NaN    75    86
# 3   NaN    78   NaN    56    45
# 4   NaN    67   NaN    78    44
# 5   NaN    56   NaN    78    57

# %%
pd.merge(data1,data2,how = 'outer')
# Out:
#     key1  key2  key3  key9  key7
# 0    1.0     9  11.0   NaN   NaN
# 1    2.0     8  43.0   NaN   NaN
# 2    4.0     7  56.0   NaN   NaN
# 3    5.0     6  76.0   NaN   NaN
# 4    6.0     5  87.0   NaN   NaN
# 5    7.0     4  98.0   NaN   NaN
# 6    NaN    32   NaN  23.0  45.0
# 7    NaN    45   NaN  45.0  76.0
# 8    NaN    76   NaN  75.0  86.0
# 9    NaN    78   NaN  56.0  45.0
# 10   NaN    67   NaN  78.0  44.0
# 11   NaN    56   NaN  78.0  57.0

# %%
data4 = pd.DataFrame({
    'key1' : [1,2,4,5,6,7],
    'key2': [9,8,7,6,5,4],
    'key3' : [11,43,56,76,87,98]
},index = ['a' , 'b' , 'c' , 'd', 'e','f'])

# %%
data5 =pd.DataFrame ({
    'key9' : [23,45,75,56,78,78],
    'key8' : [32,45,76,78,67,56],
    'key7' : [45,76,86,45,44,57]
},index =[ 'a' , 'b','i','j','k','l'])

# %%
data4
# Out:
#    key1  key2  key3
# a     1     9    11
# b     2     8    43
# c     4     7    56
# d     5     6    76
# e     6     5    87
# f     7     4    98

# %%
data5
# Out:
#    key9  key8  key7
# a    23    32    45
# b    45    45    76
# i    75    76    86
# j    56    78    45
# k    78    67    44
# l    78    56    57

# %%
data4.join(data5)
# Out:
#    key1  key2  key3  key9  key8  key7
# a     1     9    11  23.0  32.0  45.0
# b     2     8    43  45.0  45.0  76.0
# c     4     7    56   NaN   NaN   NaN
# d     5     6    76   NaN   NaN   NaN
# e     6     5    87   NaN   NaN   NaN
# f     7     4    98   NaN   NaN   NaN

# %%
# merge kaam karta hai column value ke upper
# join kaam karta hai index ke upper

data4.join(data5 , how = 'cross')
# Out:
#     key1  key2  key3  key9  key8  key7
# 0      1     9    11    23    32    45
# 1      1     9    11    45    45    76
# 2      1     9    11    75    76    86
# 3      1     9    11    56    78    45
# 4      1     9    11    78    67    44
# 5      1     9    11    78    56    57
# 6      2     8    43    23    32    45
# 7      2     8    43    45    45    76
# 8      2     8    43    75    76    86
# 9      2     8    43    56    78    45
# 10     2     8    43    78    67    44
# 11     2     8    43    78    56    57
# 12     4     7    56    23    32    45
# 13     4     7    56    45    45    76
# 14     4     7    56    75    76    86
# 15     4     7    56    56    78    45
# 16     4     7    56    78    67    44
# 17     4     7    56    78    56    57
# 18     5     6    76    23    32    45
# 19     5     6    76    45    45    76
# 20     5     6    76    75    76    86
# 21     5     6    76    56    78    45
# 22     5     6    76    78    67    44
# ...

# %%
df
# Out:
#            city  city_development_index gender      relevent_experience  \
# 0      city_103                   0.920   Male  Has relevent experience
# 1       city_40                   0.776   Male   No relevent experience
# 2       city_21                   0.624    NaN   No relevent experience
# 3      city_115                   0.789    NaN   No relevent experience
# 4      city_162                   0.767   Male  Has relevent experience
# ...         ...                     ...    ...                      ...
# 19153  city_173                   0.878   Male   No relevent experience
# 19154  city_103                   0.920   Male  Has relevent experience
# 19155  city_103                   0.920   Male  Has relevent experience
# 19156   city_65                   0.802   Male  Has relevent experience
# 19157   city_67                   0.855    NaN   No relevent experience
#
#       enrolled_university education_level major_discipline  experience  \
# ...

# %%
#new column bnaker purane wale column ke sath opration karna
df['experience_INR'] = df['experience'].apply(lambda x:x*2)

# %%
df['experience_INR']
# Out:
# 0        40.0
# 1        30.0
# 2        10.0
# 3         0.0
# 4        40.0
#          ...
# 19153    28.0
# 19154    28.0
# 19155    40.0
# 19156     0.0
# 19157     4.0
# Name: experience_INR, Length: 19158, dtype: float64

# %%
df.head()
# Out:
#        city  city_development_index gender      relevent_experience  \
# 0  city_103                   0.920   Male  Has relevent experience
# 1   city_40                   0.776   Male   No relevent experience
# 2   city_21                   0.624    NaN   No relevent experience
# 3  city_115                   0.789    NaN   No relevent experience
# 4  city_162                   0.767   Male  Has relevent experience
#
#   enrolled_university education_level major_discipline  experience  \
# 0       no_enrollment        Graduate             STEM        20.0
# 1       no_enrollment        Graduate             STEM        15.0
# 2    Full time course        Graduate             STEM         5.0
# 3                 NaN        Graduate  Business Degree         0.0
# 4       no_enrollment         Masters             STEM        20.0
#
#   company_size    company_type  training_hours  target  experience_INR
# 0          NaN             NaN            36.0     1.0            40.0
# ...

# %%
# column me jitne nhi hai sabka length nikalne ke liye alag se ek column bnaker ushka size nikalna

df['gender_len'] = df['gender'].apply(len)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 3
#       1 # column me jitne nhi hai sabka length nikalne ke liye alag se ek column bnaker ushka size nikalna
# ----> 3 df['gender_len'] = df['gender'].apply(len)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:1105, in SeriesApply.apply(self)
# ...

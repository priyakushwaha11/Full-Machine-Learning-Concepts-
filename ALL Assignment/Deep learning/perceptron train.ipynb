# %%
from sklearn.datasets import make_classification
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X,y = make_classification(n_samples=100, n_features=20, n_informative=2,
                          n_redundant=0, n_repeated=0, n_classes=2, 
                          n_clusters_per_class=1, weights=None, flip_y=0.01,
                          class_sep=1.0,hypercube=True,shuffle=False, random_state=41)

# %%
plt.figure(figsize=(10,6))
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)

# %%
## perceptron

def perceptron(X,y):
    
    X = np.insert(X,0,1,axis=1)
    weights = np.ones(X.shape[1])
    lr=0.1
    
    for i in range(1000):
        j= np.random.randint(0,100)
        y_hat = step(np.dot(x[j],weights))
        weights = weights+lr*(y[j]-y_hat)*X[j]
        
    return weights[0],weights[1:]

# %%
np.random.randint(0,100)
# Out:
# 20

# %%
def step(z):
    return 1 if z>0 else 0

# %%
intercept_coef_ = perceptron(X,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 intercept_coef_ = perceptron(X,y)
#
# Cell In[32], line 11, in perceptron(X, y)
#       9 for i in range(1000):
#      10     j= np.random.randint(0,100)
# ---> 11     y_hat = step(np.dot(x[j],weights))
#      12     weights = weights+lr*(y[j]-y_hat)*X[j]
#      14 return weights[0],weights[1:]
#
# NameError: name 'x' is not defined

# %%
np.ones(3)
# Out:
# array([1., 1., 1.])
